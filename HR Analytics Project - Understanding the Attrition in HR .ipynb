# %% [markdown]
# <div style="background-color:#ff66b2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h1 style="color:#4d004d; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; text-align: center;">
#         HR Analytics Project: Understanding the Attrition in HR 📊
#     </h1>
# </div>

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h2 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: center;">
#         Project Overview 📄
#     </h2>
# </div>

# %% [markdown]
# This project focuses on understanding and mitigating employee attrition in companies through the lens of HR Analytics. Companies invest significantly in hiring and training employees, aiming to enhance their effectiveness. However, high attrition poses challenges and costs to organizations, impacting aspects such as job postings, hiring processes, paperwork, and new hire training.
#
# __Key Points:__
#
# - ___Objective:___ Improve employee performance and achieve a better return on investment.
# - ___HR Analytics:___ Applies analytic processes to the HR department, providing insights into processes for informed decision-  making.
# - ___Attrition in HR:___ Refers to the gradual loss of employees over time, which can be problematic for companies.
# - ___Impact on Companies:___ High attrition results in significant costs and hampers the accumulation of organizational knowledge and experience.
# - ___Solution:___ Leveraging HR Analytics to analyze attrition and design effective compensation programs, work culture, and motivation systems for employee retention.
#
# __Dataset Link:__ •	https://github.com/dsrscientist/IBM_HR_Attrition_Rate_Analytics
#
# This project will delve into how HR Analytics can be utilized to tackle attrition issues, offering insights and solutions for effective employee management.

# %% [markdown]
# <div style= "background-color:#f2f2f2;padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h2 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: center;">
#         Importing Libraries and Data 📚📊
#     </h2>
# </div>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/Mahima/Documents/Internship assignments/WA_Fn-UseC_-HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# As we have 35 Columns Lets sort Columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'], object: ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']}

# %% [markdown]
# ### Data Insights 💡
#
# - __Dataset Dimensions:__ The HR dataset comprises 1470 rows and 35 columns.
#
# - __Data Integrity Check:__
# > _Missing Values:_ No missing values are observed across all columns.
# > _Data Types:_ 9 features are of object data type, and the remaining are of int64 types.
# > _Duplicates:_ Data integrity checks reveal no duplicate entries or errors in the dataset.
#
# - __Feature Information:__
# _Ordinal Variables:_ The following numeric variables are considered ordinal:
#
# > 'Education'
# 'EnvironmentSatisfaction'
# 'JobInvolvement'
# 'JobSatisfaction'
# 'RelationshipSatisfaction'
# 'PerformanceRating'
# 'WorkLifeBalance'
#
# - __Unique Ranges for Ordinal Variables:__
# > 1. _Education:_ 1 - 'Below College', 2 - 'College', 3 - 'Bachelor', 4 - 'Master', 5 - 'Doctor'
# > 2. _EnvironmentSatisfaction:_ 1 - 'Low', 2 - 'Medium', 3 - 'High', 4 - 'Very High'
# > 3. _JobInvolvement:_ 1 - 'Low', 2 - 'Medium', 3 - 'High', 4 - 'Very High'
# > 4. _JobSatisfaction:_ 1 - 'Low', 2 - 'Medium', 3 - 'High', 4 - 'Very High'
# > 5. _PerformanceRating:_ 1 - 'Low', 2 - 'Average', 3 - 'Good', 4 - 'Excellent', 5 - 'Outstanding'
# > 6. _RelationshipSatisfaction:_ 1 - 'Low', 2 - 'Medium', 3 - 'High', 4 - 'Very High'
# > 7. _WorkLifeBalance:_ 1 - 'Bad', 2 - 'Good', 3 - 'Better', 4 - 'Best'
#
# - __Target Variable:__
# ___'Attrition'___ is the target variable indicating employee attrition.
#
# __Summary:__
# The dataset is well-structured with no missing values or duplicates. Key features, including ordinal variables, are appropriately labeled, providing a foundation for in-depth analysis in the HR analytics project. The target variable 'Attrition' will be a focal point for understanding employee turnover.

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h2 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: center;">
#         Exploratory Data Analysis (EDA) 📊🔍
#     </h2>
# </div>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
missing_values
# Out:
# Age                         0
# StandardHours               0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# MonthlyIncome               0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# MonthlyRate                 0
# MaritalStatus               0
# Attrition                   0
# EmployeeCount               0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeNumber              0
# JobSatisfaction             0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='PiYG')

plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# Dataset dosen't contain any Duplicate Entry or Missing Values.

# %%
plt.figure(figsize=(28,10))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <Axes: >

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# ### Key Statistical Insights 📊
#
# ___1.Employee Age:___
# - Minimum Age: 18 years
# - Maximum Age: 60 years
#
# ___2.Distance from Home:___
# - Average Distance: 9.1 KM
# - Most employees travel at least 18 KM daily from home to the office.
#
# ___3.Performance Rating:___
# - Average Rating: 3.163
# - Minimum Rating: 3.0
# - Most employees have a 'Good' performance rating (3.0). Further investigation is needed for employees with an 'Outstanding' (5) rating.
#
# ___4.Previous Companies Worked:___
# - Median: 2 companies
# - 50% of employees have worked for at least 2 companies previously.
#
# ___5.Monthly Income and Monthly Rate:___
# Outliers are observed in the 'Monthly Income' feature.
#
# ___6.Skewed Features:___
# Some features exhibit skewness based on the difference between mean and median values.
#
# ___7.Ordinal Features:___
# For ordinal features, statistical terminology (mean, median, std deviation) might not be meaningful.
#
# ___8.StandardHours and EmployeeCount:___
# These features contain the same value for all statistical parameters, indicating a single unique value.

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
labels = 'Yes', 'No'
colormap = plt.cm.PiYG
explode = (0.1, 0.2)

fig, ax = plt.subplots()

colors = colormap(np.linspace(0, 1, len(labels)))

ax.pie(df['Attrition'].value_counts(), labels=labels, autopct='%1.1f%%', explode=explode, colors=colors, shadow=True, startangle=90, labeldistance=1.1, pctdistance=0.75)

centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

ax.axis('equal')

plt.title('Attrition Distribution')
plt.show()

# %% [markdown]
# ### Attrition Overview 📉
#
# __Attrition Rate:__
# ___Stayed:___ 83.88% (1237 employees)
# ___Left:___ 16.12% (237 employees)
#
# __Summary:__
#
# The dataset is imbalanced, with a higher percentage of employees staying in the organization (83.88%) compared to those leaving (16.12%).
# Imbalanced datasets may require special handling during machine learning model training to ensure fair and accurate predictions. Which we will do in later part.

# %%
Category=['Attrition', 'BusinessTravel', 'Department', 'EducationField',
          'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime' ]
for i in Category:
    print(i)
    print(df[i].value_counts())
    print("*"*100)
# Out:
# Attrition
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ****************************************************************************************************
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ****************************************************************************************************
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ****************************************************************************************************
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ****************************************************************************************************
# Gender
# Male      882
# ...

# %%
sns.set_palette('PiYG')

plt.figure(figsize=(20, 20), facecolor='white')
plotnumber = 1

Category = ['Attrition', 'BusinessTravel', 'Department', 'EducationField',
            'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

for i in Category:
    if plotnumber <= 9:
        ax = plt.subplot(3, 3, plotnumber)
        sns.countplot(data=df, y=i)  
        plt.xlabel('Count', fontsize=16)
        plt.ylabel(i, fontsize=20)
        plt.title(f'{i} Distribution', fontsize=18)
        plt.xticks(rotation=30)
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
Ordinal=['Education','EnvironmentSatisfaction', 'JobInvolvement','JobSatisfaction',
          'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' ]
for i in Ordinal:
    print(i)
    print(df[i].value_counts())
    print("*"*100)
# Out:
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64
# ****************************************************************************************************
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64
# ****************************************************************************************************
# JobInvolvement
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64
# ****************************************************************************************************
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
# ****************************************************************************************************
# RelationshipSatisfaction
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64
# ...

# %%
sns.set_palette('PiYG')

plt.figure(figsize=(20, 20), facecolor='white')
plotnumber = 1

Ordinal = ['Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobSatisfaction',
           'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance']

for i in Ordinal:  
    if plotnumber <= 9:
        ax = plt.subplot(3, 3, plotnumber)
        sns.countplot(data=df, y=i)
        plt.xlabel('Count', fontsize=16)
        plt.ylabel(i, fontsize=20)
        plt.title(f'{i} Distribution', fontsize=18)
        plt.xticks(rotation=30)
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
sns.set_palette('PiYG')

# Donut chart for Education Level of Employees
plt.figure(figsize=(12, 6))
plt.title('Education Level of Employees', fontsize=18)

education_counts = df['Education'].value_counts()
labels = ['Bachelor', 'Master', 'College', 'Below College', 'Doctor']  
plt.pie(education_counts, labels=labels, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')  
plt.show()

# Donut chart for Education Level by Department
departments = ['Sales', 'Research & Development', 'Human Resources']
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.suptitle('Education Level by Department', fontsize=20)

for i, department in enumerate(departments):
    department_data = df[df['Department'] == department]

    labels = department_data['Education'].value_counts().index  
    axes[i].pie(department_data['Education'].value_counts(), labels=labels,
                autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
    axes[i].set_title(f'{department} Department', fontsize=16)
    axes[i].axis('equal')
    axes[i].add_artist(plt.Circle((0, 0), 0.70, fc='white'))
    
    
# Bar plot for Education Level vs. Education Field 
plt.figure(figsize=(12, 6))
plt.title('Education Level vs. Education Field', fontsize=18)

sns.countplot(data=df, x='Education', hue='EducationField', palette='PiYG', dodge=True)

centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.show()

# %% [markdown]
# ### Employee Education Insights 🎓
#
# 1. __Education Level of Employees:__
# - ___Masters & Bachelor Education:___ More than 60% of employees have education at the Masters and Bachelor levels.
# - ___Highly Educated Employees:___ Around 30% of employees hold advanced degrees (Master and Doctor).
# - ___Graduates:___ Approximately 39% of employees have completed graduate education.
# - ___College & Below College:___ 19% are educated up to college, and 12% have education below college.
#
# 2. __Education Level by Department:__
# - ___Research & Development (R&D):___ 65.37% of employees belong to the R&D department.
# - ___Distribution in HR Department:___ Only 63 employees work in the HR department.
#
# 3. __Education Level vs. Education Field:__
# - ___Life Science Background:___ 41.22% of employees come from a Life Science background, followed by 31.56% in Medical professions.
# - ___HR Background in HR Department:___ Only 27 people have an HR background, while 63 people work in the HR department. This suggests that at least half of the HR department employees do not have an HR background.
# - ___Technical Degrees:___ Employees with technical degrees are mostly at the Bachelor's level.
# - ___Domain Alignment in R&D:___ In the R&D department, almost everyone comes from a technical or professional background, except support staff.
# - ___Marketing Background:___ There are 159 employees with a Marketing background, all working in the Sales department.
# - ___Sales Department Composition:___ 50% of employees in the sales department have a background in Life Sciences and Medical professions.
#
# __Summary:__
# - Dissatisfaction with work in a domain not aligned with education background could contribute to employee attrition.
# - Factors like salary hike, travel, overtime, and job level need consideration while analyzing attrition in technical and professional roles.
# - Attrition rates in employees with Life Science and Medical backgrounds in the sales department are worth monitoring.

# %%
sns.set_palette('PiYG')

plt.figure(figsize=(15, 7))
sns.countplot(y=df['JobRole'])  
plt.xticks(rotation=45)
plt.title('Count of Employees by Job Role', fontsize=18)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Job Role', fontsize=14)
plt.show()

# %% [markdown]
# ### Employee Job Roles 🧑‍💼
#
# - ___Sales Department:___
# Sales Executive: The majority of employees, with a total of 446, hold the role of Sales Executive.
# Sales Representative: There are 82 Sales Representatives.
# - ___Human Resources (HR) Department:___
# HR & Manager Roles: The HR department consists of two job roles: HR and Manager.
# - ___Research & Development (R&D) Department:___
# Various Job Roles: The R&D department has a diverse set of job roles with a total of 961 employees.
# Specific Domain Background: Each employee in the R&D department belongs to their respective domain background.
#
# __Summary:__
# - The sales department is dominated by Sales Executives, indicating a sales-centric workforce.
# - The HR department has roles specific to human resources management.
# - The R&D department showcases a variety of job roles, aligning with the diverse nature of research and development activities.

# %%
pd.crosstab([df.JobRole],[df.Department], margins=True)
# Out:
# Department                 Human Resources  Research & Development  Sales  \
# JobRole
# Healthcare Representative                0                     131      0
# Human Resources                         52                       0      0
# Laboratory Technician                    0                     259      0
# Manager                                 11                      54     37
# Manufacturing Director                   0                     145      0
# Research Director                        0                      80      0
# Research Scientist                       0                     292      0
# Sales Executive                          0                       0    326
# Sales Representative                     0                       0     83
# All                                     63                     961    446
#
# Department                  All
# JobRole
# Healthcare Representative   131
# Human Resources              52
# Laboratory Technician       259
# ...

# %%
# Crosstab for Job Role vs. Department
plt.figure(figsize=(12, 10))

# Stacked Bar Plot for Attrition as per Job Role
plt.figure(figsize=(12, 8))
data = pd.crosstab(df['JobRole'], df['Attrition'])

data_percentage = data.div(data.sum(1).astype(float), axis=0) * 100
colors = sns.color_palette('PiYG', n_colors=data_percentage.shape[1])

data_percentage.plot(kind='bar', stacked=True, color=colors, figsize=(12, 8))
plt.title('Attrition Percentage by Job Role', fontsize=20)
plt.xlabel('Job Role', fontsize=15)
plt.ylabel('Attrition Percentage', fontsize=15)
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
# Create crosstab
crosstab_data = pd.crosstab([df.JobRole, df.Department], [df.Attrition], margins=True)
crosstab_data
# Out:
# Attrition                                           No  Yes   All
# JobRole                   Department
# Healthcare Representative Research & Development   122    9   131
# Human Resources           Human Resources           40   12    52
# Laboratory Technician     Research & Development   197   62   259
# Manager                   Human Resources           11    0    11
#                           Research & Development    51    3    54
#                           Sales                     35    2    37
# Manufacturing Director    Research & Development   135   10   145
# Research Director         Research & Development    78    2    80
# Research Scientist        Research & Development   245   47   292
# Sales Executive           Sales                    269   57   326
# Sales Representative      Sales                     50   33    83
# All                                               1233  237  1470

# %% [markdown]
# ### Attrition Analysis by Job Role 🚀
#
# __1.High Attrition Roles:__
# - Sales Representative: Highest attrition rate.
# - Laboratory Technician: Significant attrition.
# - Human Resources Roles: Also experiencing considerable attrition.
#
# __2.Top Attrition Roles:__
# - Laboratory Technicians: 62 employees.
# - Sales Executives: 57 employees.
# - Research Scientists: 47 employees.
#
# __Summary:__
# - Roles with lower corporate hierarchy and comparatively lower salaries show higher attrition.
# - Monthly Income, Job Satisfaction, and Traveling factors need deeper exploration for these roles.
# - Notable concern: High attrition in Research Scientist roles (16%), impacting company's investment in knowledge and expertise.

# %%
# Grouping Numeric Features
Numeric=['Age', 'DailyRate', 'DistanceFromHome',  
 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 
 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 
 'RelationshipSatisfaction','StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
Numeric_int = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate',
               'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear',
               'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

sns.set_palette(['#008000'])  
plt.figure(figsize=(20, 50), facecolor='white')
plotnumber = 1

for i in Numeric_int:
    if plotnumber <= 25:
        ax = plt.subplot(9, 3, plotnumber)
        sns.violinplot(x=df[i], color='#008000', orient='v') 
        plt.xlabel(i, fontsize=20)
    plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights from the graph
#
# 1. __Tenure Distribution:__
# Majority of employees have a tenure of 3 to 10 years in the company.
# 2. __Years Since Last Promotion:__
# A significant number of employees leave within 2 years after promotion.
# 3. __Training Frequency:__
# - Most employees receive training 2-3 times in the last year.
# - Attrition can result in loss of training investments for the company.
# 4. __Job Role Duration:__
# The majority of employees stay in the same role for a maximum of 4 years.
# 5. __Salary Hike Range:__
# Most employees experience a salary hike in the range of 10% to 15%.
#
# __Summary:__
# Understanding patterns in tenure, promotion impact, training, role duration, and salary hikes is crucial for strategic employee retention and development programs.
#
# __Key Takeaway:__
# Implementing targeted retention strategies based on these patterns can enhance employee satisfaction and longevity within the organization.

# %%
sns.set_palette('PiYG')

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
fig.suptitle('Relationships with Attrition', fontsize=20)

# Age vs Attrition 
sns.barplot(x=df['Attrition'], y=df['Age'], ax=axes[0, 0])
axes[0, 0].set_title('Age vs Attrition')

# MonthlyIncome vs Attrition 
sns.barplot(x=df['Attrition'], y=df['MonthlyIncome'], ax=axes[0, 1])
axes[0, 1].set_title('MonthlyIncome vs Attrition')

# YearsSinceLastPromotion vs Attrition 
sns.barplot(x=df['Attrition'], y=df['YearsSinceLastPromotion'], ax=axes[1, 0])
axes[1, 0].set_title('YearsSinceLastPromotion vs Attrition')

# TotalWorkingYears vs MonthlyIncome 
sns.barplot(x=df['Attrition'], y=df['TotalWorkingYears'], ax=axes[1, 1])
axes[1, 1].set_title('TotalWorkingYears vs MonthlyIncome')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# 1. __Age vs Attrition:__
# - Minimum Attrition Rate: Age 34 to 35.
# - Maximum Attrition Rate: Age 29 to 31.
# 2. __Monthly Income vs Attrition:__
# Lower Attrition: Higher monthly income (reduced attrition when income reaches $6900).
# 3. __Years Since Last Promotion vs Attrition:__
# High Attrition: Employees not promoted for approximately 1.8 years.
# 4. __Total Working Years vs Monthly Income:__
# Highest Monthly Income: Employees with 21 or more Total Working Years.
#
# __Summary:__
# Understanding the correlation between age, income, promotion frequency, and total working years provides valuable insights for targeted retention strategies.
#
# __Key Takeaway:__
# Implementing focused programs for mid-career employees, promoting timely, and recognizing long-serving employees can contribute to reducing attrition.

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h2 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: center;">
#         Data Wrangling 🧹✨
#     </h2>
# </div>

# %%
# Using Label Encoder on target variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Attrition"] = le.fit_transform(df["Attrition"])
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Droping unnecessary columns
df.drop(["EmployeeCount", "EmployeeNumber", "Over18", "StandardHours"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1470, 31)

# %%
# Ordinal Encoding for ordinal variables
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
def ordinal_encode(df, column):
    df[column] = oe.fit_transform(df[column])
    return df

oe_col = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
df=ordinal_encode(df, oe_col)
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1             2.0       1102         2.0                 1
# 1   49          0             1.0        279         1.0                 8
# 2   37          1             2.0       1373         1.0                 2
# 3   33          0             1.0       1392         1.0                 3
# 4   27          0             2.0        591         1.0                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2             1.0                        2     0.0  ...
# 1          1             1.0                        3     1.0  ...
# 2          2             4.0                        4     1.0  ...
# 3          4             1.0                        4     0.0  ...
# 4          1             3.0                        1     1.0  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h3 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: left;">
#         1.Outliers Detection and Handling 📉🛠️
#     </h3>
# </div>

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in Numeric:
    if plotnumber<=28:
        ax=plt.subplot(7,4,plotnumber)
        sns.boxplot(df[column],color='m')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# __Following Features contains outliers :__
# "MonthlyIncome", "NumCompaniesWorked", "PerformanceRating", "StockOptionLevel", "TotalWorkingYears", "TrainingTimesLastYear", "YearsAtCompany", "YearsInCurrentRole", "YearsSinceLastPromotion", "YearsWithCurrManager", "Attrition".

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy()
# Out:
# Shape of the dataframe before removing outliers:  (1470, 31)
# Shape of the dataframe after removing outliers:  (1387, 31)
# Percentage of data loss post outlier removal:  5.646258503401361

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h3 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: left;">
#         2.Skewness and Transformation 📈🔄
#     </h3>
# </div>

# %%
df.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# ...

# %%
# Splitting data in target and dependent feature
X = df.drop(['Attrition'], axis =1)
Y = df['Attrition']

# %%
# Transforming skew data using power transform
from sklearn.preprocessing import power_transform
df = power_transform(X)
df = pd.DataFrame(df, columns=X.columns)
df.skew()
# Out:
# Age                        -0.004079
# BusinessTravel             -0.960583
# DailyRate                  -0.199742
# Department                  0.015095
# DistanceFromHome           -0.008149
# Education                  -0.103747
# EducationField             -0.008642
# EnvironmentSatisfaction    -0.205472
# Gender                     -0.417296
# HourlyRate                 -0.105678
# JobInvolvement             -0.018801
# JobLevel                    0.110769
# JobRole                    -0.337641
# JobSatisfaction            -0.217730
# MaritalStatus              -0.158253
# MonthlyIncome               0.027700
# MonthlyRate                -0.176560
# NumCompaniesWorked          0.016175
# OverTime                    0.954751
# PercentSalaryHike           0.112128
# PerformanceRating           0.000000
# RelationshipSatisfaction   -0.191406
# StockOptionLevel            0.089929
# TotalWorkingYears          -0.009666
# TrainingTimesLastYear       0.057949
# ...

# %% [markdown]
# As we can see the skewness for Numeric features are transformed within permissible limit. Whereas, for ordinal features & categorical features skewness is irrevalent.

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h3 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: left;">
#         3.Multicollinearity Analysis 📊🔄
#     </h3>
# </div>

# %%
df.corr()
# Out:
#                                Age  BusinessTravel  DailyRate  Department  \
# Age                       1.000000        0.019607   0.019864   -0.036344
# BusinessTravel            0.019607        1.000000  -0.001984   -0.003560
# DailyRate                 0.019864       -0.001984   1.000000   -0.003546
# Department               -0.036344       -0.003560  -0.003546    1.000000
# DistanceFromHome         -0.025855       -0.007041  -0.006034    0.037834
# Education                 0.215520       -0.006468  -0.017504    0.012780
# EducationField           -0.037564        0.034658   0.040993    0.082525
# EnvironmentSatisfaction   0.013967        0.004183   0.034324   -0.013867
# Gender                   -0.037163       -0.011439  -0.003271   -0.030950
# HourlyRate                0.026203        0.026364   0.015156   -0.000623
# JobInvolvement            0.032323        0.018230   0.041841   -0.025121
# JobLevel                  0.442350        0.003401   0.015931    0.200829
# ...

# %%
plt.figure(figsize=(18, 6))
df1.corr()['Attrition'].drop(['Attrition']).plot(kind='bar', color='lightgreen')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Attrition', fontsize=15)
plt.title('Correlation of Features with Target Variable Attrition', fontsize=18)
plt.show()

# %%
# Checking Multicollinearity between features using variance_inflation_factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['Features']= df.columns
vif
# Out:
#          VIF                  Features
# 0   1.930457                       Age
# 1   1.014314            BusinessTravel
# 2   1.025841                 DailyRate
# 3   2.172093                Department
# 4   1.017385          DistanceFromHome
# 5   1.065266                 Education
# 6   1.030480            EducationField
# 7   1.024396   EnvironmentSatisfaction
# 8   1.024366                    Gender
# 9   1.024189                HourlyRate
# 10  1.020167            JobInvolvement
# 11  5.976707                  JobLevel
# 12  2.023213                   JobRole
# 13  1.023909           JobSatisfaction
# 14  2.298943             MaritalStatus
# 15  5.842828             MonthlyIncome
# 16  1.022108               MonthlyRate
# 17  1.426763        NumCompaniesWorked
# 18  1.028400                  OverTime
# 19  1.016867         PercentSalaryHike
# 20  1.747581         PerformanceRating
# 21  1.022260  RelationshipSatisfaction
# 22  2.279101          StockOptionLevel
# ...

# %% [markdown]
# We can see that multicollinerity is within permissible limit of 10.

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h2 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: center;">
#         Data Balancing 🔄⚖️
#     </h2>
# </div>

# %%
# As data is Imbalanced in nature we will need to balance target variable using SMOTE.
from imblearn.over_sampling import SMOTE

oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 1    1158
# 0    1158
# Name: Attrition, dtype: int64

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h2 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align: center;">
#         Feature Scaling & Selection 🎯🔍
#     </h2>
# </div>

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

pca = PCA()

# Plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

light_pink = '#FFB6C1'  # Hex color code for light pink

plt.figure(figsize=(10, 10))
plt.plot(cumulative_variance, 'ro-', color=light_pink)
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained Variance Ratio')
plt.grid()
plt.show()

# %% [markdown]
# We can see the first 21 principal components attribute for 90% of variation in the data. Hence, We will work on the same for prediction.

# %%
pca_new = PCA(n_components=21)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(21))

# %% [markdown]
# <div style="background-color:#f2f2f2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h2 style="color:#4d004d; font-family: 'Times New Roman', serif; text-align : center;">
#         Machine Learning Model Building 🤖🔨
#     </h2>
# </div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from xgboost import XGBClassifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1551, 21)
# Training target vector size: (1551,)
# Test feature matrix size: (765, 21)
# Test target vector size: (765,)

# %%
# Finding best Random state
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.30, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.8762589928057554 on Random_state 53

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=75, test_size=.30)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.8575539568345324
#
#
# Confusion matrix of Logistics Regression :
#  [[300  45]
#  [ 54 296]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       345
#            1       0.87      0.85      0.86       350
#
#     accuracy                           0.86       695
#    macro avg       0.86      0.86      0.86       695
# weighted avg       0.86      0.86      0.86       695

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error

rmse_val = [] 

for K in range(30):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  
    y_pred=model.predict(X_test) 
    error = sqrt(mean_squared_error(Y_test,y_pred)) 
    rmse_val.append(error) 
    
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.3285021599088021
# RMSE value for k=  2 is: 0.2628017279270417
# RMSE value for k=  3 is: 0.35583522174732957
# RMSE value for k=  4 is: 0.3034572967243526
# RMSE value for k=  5 is: 0.3598560863424403
# RMSE value for k=  6 is: 0.33068492252537235
# RMSE value for k=  7 is: 0.3618497641267176
# RMSE value for k=  8 is: 0.35583522174732957
# RMSE value for k=  9 is: 0.3793216209054408
# RMSE value for k=  10 is: 0.3578513014603056
# RMSE value for k=  11 is: 0.3793216209054408
# RMSE value for k=  12 is: 0.3598560863424403
# RMSE value for k=  13 is: 0.3774202474238334
# RMSE value for k=  14 is: 0.363832517402478
# RMSE value for k=  15 is: 0.39237333565416255
# RMSE value for k=  16 is: 0.3793216209054408
# RMSE value for k=  17 is: 0.3978358723078702
# RMSE value for k=  18 is: 0.3793216209054408
# RMSE value for k=  19 is: 0.3905355113322101
# RMSE value for k=  20 is: 0.3793216209054408
# RMSE value for k=  21 is: 0.39420259189056256
# ...

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(30), rmse_val, color='lightgreen', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# The minimum RMSE value __(0.2628017279270417)__ is at __K = 2__, and increases further with increase in the k value. Hence, K= 2 will achieve best results.

# %%
# Applying other classification algorithm
model=[
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 22),
        RandomForestClassifier(),
        AdaBoostClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier(),
        XGBClassifier()]

for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('*'*110)
# Out:
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.9338129496402877
#
#
# Confusion matrix :
#  [[327  18]
#  [ 28 322]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       345
#            1       0.95      0.92      0.93       350
#
#     accuracy                           0.93       695
#    macro avg       0.93      0.93      0.93       695
# weighted avg       0.93      0.93      0.93       695
#
#
#
# **************************************************************************************************************
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.8517985611510791
#
#
# Confusion matrix :
#  [[300  45]
#  [ 58 292]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       345
# ...

# %%
from sklearn.model_selection import cross_val_score

model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 12),
        RandomForestClassifier(),
        AdaBoostClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier()]

for m in model:
    score = cross_val_score(m, X, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('*'*110)
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.6487069  0.7062635  0.64146868 0.71922246 0.71058315]
# Mean Score : 0.6852489387055931
# Std deviation : 0.03313507552157603
#
#
# **************************************************************************************************************
#
#
# Cross Validation Score SVC() :
#
# Score : [0.58189655 0.63714903 0.57883369 0.63282937 0.58531317]
# Mean Score : 0.6032043643405078
# Std deviation : 0.02606886463203373
#
#
# **************************************************************************************************************
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.67241379 0.76241901 0.71058315 0.77969762 0.77321814]
# Mean Score : 0.7396663439338645
# Std deviation : 0.041508186686521745
#
#
# **************************************************************************************************************
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# ...

# %% [markdown]
# __Random Forest Classsifier__ has the maximum cross validation score, Now let's apply Hyper tunning on the same.

# %%
from sklearn.model_selection import GridSearchCV

parameter = {  'bootstrap': [True], 'max_depth': [5, 10,20,40,50, None], 
              'max_features': ['auto', 'log2'], 
              'criterion':['gini','entropy'],
              'n_estimators': [5, 10, 15 ,25,50,100]}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameter,cv=5,n_jobs = -1,verbose=3)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 20, 40, 50, None],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [5, 10, 15, 25, 50, 100]},
#              verbose=3)

# %%
GCV.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'log2',
#  'n_estimators': 100}

# %% [markdown]
# </div>
# <div style="background-color:#ff66b2; padding:20px; border-radius: 10px; box-shadow: 5px 5px 10px #ccc;">
#     <h1 style="color:#4d004d; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; text-align: center;">
#         Final Model: Random Forest Classifier 🌲
#     </h1>
# </div>

# %%
Final_mod = RandomForestClassifier(bootstrap = True, criterion = 'gini', max_depth = None, max_features = 'log2')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.9179856115107914

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

y_pred_prob = Final_mod.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(Y_test, y_pred_prob)

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Random Forest Classifier', color='lightpink')  # Specify light pink color
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m' + 'AUC Score :' + '\033[0m\n', auc_score)
# Out:
# AUC Score :
#  0.9181573498964802

# %%
import joblib
joblib.dump(Final_mod,'IBM_HR_Analytics_Final.pkl')
# Out:
# ['IBM_HR_Analytics_Final.pkl']
